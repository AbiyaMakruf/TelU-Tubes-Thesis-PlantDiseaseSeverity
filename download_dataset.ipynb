# %% [markdown]
# # Import library

# %%
from roboflow import Roboflow

# %% [markdown]
# # Dataset for object detection

# %%
# Dataset For Object Detection All Class
rf = Roboflow(api_key="MQdx0fMQ8FiQPaS1VHRH")
project = rf.workspace("abiya-thesis").project("plant-pathology-2021-object-detection-j1jvh")
version = project.version(9)
dataset = version.download("yolov12", location="dataset_collection/roboflow/object_detection/object_detection_all_class")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to dataset_collection/roboflow/object_detection/object_detection_all_class in yolov12:: 100%|██████████| 1512/1512 [00:01<00:00, 1038.05it/s]

# %%
# Dataset For Object Detection All Class with Augmentation
# Flip: Horizontal, Vertical
# Brightness: Between -25% and +25%
# Train set from 525 to 1050
rf = Roboflow(api_key="MQdx0fMQ8FiQPaS1VHRH")
project = rf.workspace("abiya-thesis").project("plant-pathology-2021-object-detection-j1jvh")
version = project.version(10)
dataset = version.download("yolov12", location="dataset_collection/roboflow/object_detection/object_detection_all_class_with_augmentation")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to dataset_collection/roboflow/object_detection/object_detection_all_class_with_augmentation in yolov12:: 100%|██████████| 2562/2562 [00:01<00:00, 2269.46it/s]

# %%
# Dataset For Object Detection Frog Eye Leaf Spot Class
rf = Roboflow(api_key="MQdx0fMQ8FiQPaS1VHRH")
project = rf.workspace("abiya-thesis").project("plant-pathology-2021-object-detection-j1jvh")
version = project.version(6)
dataset = version.download("yolov12", location="dataset_collection/roboflow/object_detection/object_detection_frog_eye_leaf_spot")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov12 in progress : 85.0%
# Version export complete for yolov12 format
# ...
# Extracting Dataset Version Zip to dataset_collection/roboflow/object_detection/object_detection_frog_eye_leaf_spot in yolov12:: 100%|██████████| 512/512 [00:00<00:00, 1230.44it/s]

# %%
# Dataset For Object Detection Healthy Class
rf = Roboflow(api_key="MQdx0fMQ8FiQPaS1VHRH")
project = rf.workspace("abiya-thesis").project("plant-pathology-2021-object-detection-j1jvh")
version = project.version(7)
dataset = version.download("yolov12", location="dataset_collection/roboflow/object_detection/object_detection_healthy")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov12 in progress : 85.0%
# Version export complete for yolov12 format
# ...
# Extracting Dataset Version Zip to dataset_collection/roboflow/object_detection/object_detection_healthy in yolov12:: 100%|██████████| 512/512 [00:00<00:00, 607.03it/s]

# %%
# Dataset For Object Detection Rust Class
rf = Roboflow(api_key="MQdx0fMQ8FiQPaS1VHRH")
project = rf.workspace("abiya-thesis").project("plant-pathology-2021-object-detection-j1jvh")
version = project.version(8)
dataset = version.download("yolov12", location="dataset_collection/roboflow/object_detection/object_detection_rust")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov12 in progress : 85.0%
# Version export complete for yolov12 format
# ...
# Extracting Dataset Version Zip to dataset_collection/roboflow/object_detection/object_detection_rust in yolov12:: 100%|██████████| 512/512 [00:00<00:00, 991.33it/s]

# %%
# Dataset For Object Detection Few Shot (Healthy + Rust)
rf = Roboflow(api_key="XufIgI94wgR9n3u7GKJT")
project = rf.workspace("abiyamf").project("plant-pathology-2021-object-detection-j1jvh-4mznp")
version = project.version(2)
dataset = version.download("yolov12", location="dataset_collection/roboflow/object_detection/object_detection_few_shot_healthy_rust")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to dataset_collection/roboflow/object_detection/object_detection_few_shot_healthy_rust in yolov12:: 100%|██████████| 1012/1012 [00:00<00:00, 2321.00it/s]

# %%
# Dataset For Object Detection 10K Images
rf = Roboflow(api_key="MQdx0fMQ8FiQPaS1VHRH")
project = rf.workspace("abiya-thesis").project("plant-pathology-2021-object-detection-j1jvh")
version = project.version(12)
dataset = version.download("yolov12", location="dataset_collection/roboflow/object_detection/object_detection_all_class_10k_images")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to dataset_collection/roboflow/object_detection/object_detection_10k_images in yolov12:: 100%|██████████| 21854/21854 [00:07<00:00, 2748.22it/s]

# %% [markdown]
# # Dataset for segmentation

# %%
# Dataset For Segmentation Mask Leaf and Lession
rf = Roboflow(api_key="MQdx0fMQ8FiQPaS1VHRH")
project = rf.workspace("abiya-thesis").project("plant-pathology-2021-instance-segmentation-h5pim")
version = project.version(5)
dataset = version.download("yolov12", location="dataset_collection/roboflow/segmentation/segmentation_mask_leaf_and_lession")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to dataset_collection/roboflow/segmentation/segmentation_mask_leaf_and_lession in yolov12:: 100%|██████████| 1512/1512 [00:01<00:00, 944.86it/s]

# %%
# Dataset For Segmentation Mask Leaf
rf = Roboflow(api_key="MQdx0fMQ8FiQPaS1VHRH")
project = rf.workspace("abiya-thesis").project("plant-pathology-2021-instance-segmentation-h5pim")
version = project.version(6)
dataset = version.download("yolov12", location="dataset_collection/roboflow/segmentation/segmentation_mask_leaf")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov12 in progress : 85.0%
# Version export complete for yolov12 format
# ...
# Extracting Dataset Version Zip to dataset_collection/roboflow/segmentation/segmentation_mask_leaf in yolov12:: 100%|██████████| 1512/1512 [00:01<00:00, 1275.60it/s]

# %%
# Dataset For Segmentation Mask Lesi
rf = Roboflow(api_key="MQdx0fMQ8FiQPaS1VHRH")
project = rf.workspace("abiya-thesis").project("plant-pathology-2021-instance-segmentation-h5pim")
version = project.version(7)
dataset = version.download("yolov12", location="dataset_collection/roboflow/segmentation/segmentation_mask_lession")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov12 in progress : 85.0%
# Version export complete for yolov12 format
# ...
# Extracting Dataset Version Zip to dataset_collection/roboflow/segmentation/segmentation_mask_lession in yolov12:: 100%|██████████| 1512/1512 [00:01<00:00, 1123.49it/s]
