# %%
import os
from PIL import Image
from ultralytics import YOLO

# 1. Ganti dengan path model Anda
# 'yolo11n.pt' kemungkinan adalah nama custom. Gunakan model resmi seperti 'yolov8n.pt'
# atau path ke model hasil training Anda, contoh: 'runs/segment/penyakit_tanaman_yolov8s/weights/best.pt'
MODEL_PATH = "runs_seg/runs_seg/segment/train/weights/best.pt" 

# 2. Ganti dengan path ke folder gambar Anda
INPUT_FOLDER = "Plant-Pathology-Anotation-7/valid/images/"

# 3. Nama folder untuk menyimpan hasil
OUTPUT_FOLDER = "output_inference/"

# --- Mulai Script ---

# Buat folder output jika belum ada
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# Muat model YOLO yang sudah di-train
model = YOLO(MODEL_PATH)

# Dapatkan daftar semua path gambar di dalam folder input
# Script akan mencari file dengan ekstensi .jpg, .jpeg, dan .png
image_paths = [os.path.join(INPUT_FOLDER, f) for f in os.listdir(INPUT_FOLDER) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

if not image_paths:
    print(f"Tidak ada gambar yang ditemukan di folder: {INPUT_FOLDER}")
else:
    # Jalankan inference pada semua gambar yang ditemukan
    results = model(image_paths)

    # Lakukan iterasi pada setiap hasil untuk visualisasi dan penyimpanan
    print(f"Memproses {len(results)} gambar. Hasil akan disimpan di '{OUTPUT_FOLDER}'...")
    for i, r in enumerate(results):
        # Plot hasil (menggambar bounding box/segmentasi pada gambar)
        im_bgr = r.plot()  # Hasil dalam format array numpy BGR
        im_rgb = Image.fromarray(im_bgr[..., ::-1])  # Konversi ke PIL Image RGB

        # Dapatkan nama file asli untuk penamaan file output
        original_filename = os.path.basename(r.path)
        
        # Simpan hasil ke disk dengan nama yang deskriptif
        output_filename = f"result_{original_filename}"
        r.save(filename=os.path.join(OUTPUT_FOLDER, output_filename))

        # Tampilkan hasil ke layar (jika environment mendukung)
        # r.show() # Baris ini bisa diaktifkan jika Anda ingin menampilkan setiap gambar

    print("Selesai!")
# Out:
# 0: 448x640 1 leaf_healthy, 789.8ms
# 1: 448x640 2 leaf_rusts, 789.8ms
# 2: 448x640 1 leaf_rust, 789.8ms
# 3: 448x640 2 leaf_scabs, 789.8ms
# 4: 448x640 1 leaf_rust, 789.8ms
# 5: 448x640 1 leaf_scab, 789.8ms
# 6: 448x640 1 leaf_scab, 789.8ms
# 7: 448x640 4 leaf_healthys, 789.8ms
# 8: 448x640 1 leaf_scab, 789.8ms
# 9: 448x640 1 leaf_rust, 789.8ms
# 10: 448x640 2 leaf_rusts, 789.8ms
# 11: 448x640 5 leaf_healthys, 789.8ms
# 12: 448x640 3 leaf_rusts, 789.8ms
# 13: 448x640 1 leaf_scab, 789.8ms
# 14: 448x640 6 leaf_healthys, 789.8ms
# 15: 448x640 1 leaf_scab, 789.8ms
# 16: 448x640 3 leaf_rusts, 789.8ms
# 17: 448x640 2 leaf_scabs, 789.8ms
# 18: 448x640 1 leaf_healthy, 789.8ms
# 19: 448x640 1 leaf_rust, 789.8ms
# 20: 448x640 1 leaf_scab, 789.8ms
# 21: 448x640 1 leaf_rust, 789.8ms
# 22: 448x640 1 leaf_scab, 789.8ms
# 23: 448x640 5 leaf_healthys, 789.8ms
# 24: 448x640 1 leaf_rust, 789.8ms
# 25: 448x640 4 leaf_healthys, 789.8ms
# 26: 448x640 1 leaf_rust, 789.8ms
# 27: 448x640 2 leaf_healthys, 789.8ms
# 28: 448x640 1 leaf_scab, 789.8ms
# 29: 448x640 3 leaf_scabs, 789.8ms
# 30: 448x640 1 leaf_scab, 789.8ms
# 31: 448x640 1 leaf_rust, 789.8ms
# 32: 448x640 1 leaf_scab, 789.8ms
# 33: 448x640 3 leaf_healthys, 789.8ms
# 34: 448x640 1 leaf_scab, 789.8ms
# 35: 448x640 1 leaf_scab, 789.8ms
# 36: 448x640 1 leaf_rust, 789.8ms
# 37: 448x640 3 leaf_healthys, 789.8ms
# 38: 448x640 1 leaf_rust, 789.8ms
# 39: 448x640 3 leaf_healthys, 789.8ms
# 40: 448x640 2 leaf_healthys, 789.8ms
# 41: 448x640 1 leaf_scab, 789.8ms
# 42: 448x640 1 leaf_rust, 789.8ms
# 43: 448x640 4 leaf_rusts, 789.8ms
# 44: 448x640 1 leaf_scab, 789.8ms
# 45: 448x640 1 leaf_rust, 789.8ms
# 46: 448x640 1 leaf_rust, 789.8ms
# 47: 448x640 7 leaf_healthys, 789.8ms
# 48: 448x640 1 leaf_rust, 789.8ms
# 49: 448x640 1 leaf_scab, 789.8ms
# 50: 448x640 1 leaf_scab, 789.8ms
# 51: 448x640 2 leaf_scabs, 789.8ms
# 52: 448x640 1 leaf_healthy, 2 leaf_scabs, 789.8ms
# 53: 448x640 7 leaf_healthys, 789.8ms
# 54: 448x640 2 leaf_healthys, 789.8ms
# 55: 448x640 1 leaf_rust, 789.8ms
# 56: 448x640 1 leaf_rust, 789.8ms
# 57: 448x640 2 leaf_rusts, 789.8ms
# 58: 448x640 2 leaf_scabs, 789.8ms
# 59: 448x640 2 leaf_healthys, 789.8ms
# 60: 448x640 2 leaf_healthys, 789.8ms
# 61: 448x640 5 leaf_healthys, 789.8ms
# 62: 448x640 2 leaf_healthys, 1 leaf_rust, 789.8ms
# 63: 448x640 1 leaf_scab, 789.8ms
# 64: 448x640 1 leaf_rust, 789.8ms
# 65: 448x640 3 leaf_healthys, 789.8ms
# 66: 448x640 4 leaf_healthys, 789.8ms
# 67: 448x640 1 leaf_rust, 789.8ms
# 68: 448x640 1 leaf_scab, 789.8ms
# 69: 448x640 1 leaf_scab, 789.8ms
# 70: 448x640 4 leaf_rusts, 789.8ms
# 71: 448x640 1 leaf_rust, 789.8ms
# 72: 448x640 1 leaf_rust, 789.8ms
# 73: 448x640 1 leaf_scab, 789.8ms
# 74: 448x640 2 leaf_rusts, 789.8ms
# 75: 448x640 2 leaf_rusts, 789.8ms
# 76: 448x640 1 leaf_scab, 789.8ms
# 77: 448x640 6 leaf_healthys, 789.8ms
# 78: 448x640 3 leaf_healthys, 789.8ms
# 79: 448x640 1 leaf_scab, 789.8ms
# 80: 448x640 2 leaf_scabs, 789.8ms
# 81: 448x640 1 leaf_scab, 789.8ms
# 82: 448x640 1 leaf_rust, 789.8ms
# 83: 448x640 3 leaf_rusts, 789.8ms
# 84: 448x640 1 leaf_rust, 789.8ms
# 85: 448x640 2 leaf_healthys, 789.8ms
# 86: 448x640 5 leaf_healthys, 789.8ms
# 87: 448x640 7 leaf_healthys, 789.8ms
# 88: 448x640 2 leaf_healthys, 789.8ms
# 89: 448x640 1 leaf_healthy, 1 leaf_rust, 789.8ms
# 90: 448x640 1 leaf_rust, 789.8ms
# 91: 448x640 1 leaf_scab, 789.8ms
# 92: 448x640 1 leaf_scab, 789.8ms
# 93: 448x640 6 leaf_healthys, 789.8ms
# 94: 448x640 1 leaf_scab, 789.8ms
# 95: 448x640 1 leaf_rust, 789.8ms
# 96: 448x640 4 leaf_healthys, 789.8ms
# 97: 448x640 4 leaf_healthys, 789.8ms
# 98: 448x640 2 leaf_scabs, 789.8ms
# 99: 448x640 1 leaf_rust, 789.8ms
# 100: 448x640 1 leaf_scab, 789.8ms
# 101: 448x640 2 leaf_rusts, 789.8ms
# 102: 448x640 3 leaf_healthys, 789.8ms
# 103: 448x640 2 leaf_scabs, 789.8ms
# 104: 448x640 3 leaf_healthys, 789.8ms
# 105: 448x640 1 leaf_scab, 789.8ms
# 106: 448x640 1 leaf_scab, 789.8ms
# 107: 448x640 3 leaf_scabs, 789.8ms
# 108: 448x640 1 leaf_rust, 789.8ms
# 109: 448x640 9 leaf_healthys, 789.8ms
# 110: 448x640 3 leaf_healthys, 789.8ms
# 111: 448x640 1 leaf_scab, 789.8ms
# 112: 448x640 1 leaf_scab, 789.8ms
# 113: 448x640 1 leaf_scab, 789.8ms
# 114: 448x640 2 leaf_scabs, 789.8ms
# 115: 448x640 11 leaf_healthys, 789.8ms
# 116: 448x640 8 leaf_healthys, 789.8ms
# 117: 448x640 1 leaf_scab, 789.8ms
# 118: 448x640 1 leaf_rust, 789.8ms
# 119: 448x640 1 leaf_scab, 789.8ms
# 120: 448x640 1 leaf_scab, 789.8ms
# 121: 448x640 3 leaf_rusts, 789.8ms
# 122: 448x640 4 leaf_healthys, 789.8ms
# 123: 448x640 2 leaf_rusts, 789.8ms
# 124: 448x640 3 leaf_healthys, 789.8ms
# 125: 448x640 1 leaf_scab, 789.8ms
# 126: 448x640 1 leaf_rust, 789.8ms
# 127: 448x640 1 leaf_scab, 789.8ms
# 128: 448x640 2 leaf_healthys, 789.8ms
# 129: 448x640 3 leaf_healthys, 789.8ms
# 130: 448x640 7 leaf_healthys, 789.8ms
# 131: 448x640 1 leaf_scab, 789.8ms
# 132: 448x640 1 leaf_rust, 789.8ms
# 133: 448x640 2 leaf_scabs, 789.8ms
# 134: 448x640 1 leaf_scab, 789.8ms
# 135: 448x640 1 leaf_rust, 789.8ms
# 136: 448x640 1 leaf_scab, 789.8ms
# 137: 448x640 2 leaf_rusts, 789.8ms
# 138: 448x640 2 leaf_healthys, 789.8ms
# 139: 448x640 1 leaf_rust, 789.8ms
# 140: 448x640 1 leaf_rust, 789.8ms
# 141: 448x640 9 leaf_healthys, 789.8ms
# 142: 448x640 4 leaf_healthys, 789.8ms
# 143: 448x640 3 leaf_healthys, 789.8ms
# 144: 448x640 1 leaf_scab, 789.8ms
# 145: 448x640 8 leaf_healthys, 789.8ms
# 146: 448x640 1 leaf_rust, 789.8ms
# 147: 448x640 1 leaf_rust, 789.8ms
# 148: 448x640 5 leaf_healthys, 789.8ms
# 149: 448x640 1 leaf_scab, 789.8ms
# 150: 448x640 1 leaf_scab, 789.8ms
# 151: 448x640 2 leaf_healthys, 789.8ms
# 152: 448x640 3 leaf_rusts, 789.8ms
# 153: 448x640 10 leaf_healthys, 789.8ms
# 154: 448x640 3 leaf_rusts, 789.8ms
# 155: 448x640 1 leaf_rust, 789.8ms
# 156: 448x640 1 leaf_rust, 789.8ms
# 157: 448x640 6 leaf_healthys, 789.8ms
# 158: 448x640 1 leaf_scab, 789.8ms
# 159: 448x640 1 leaf_rust, 789.8ms
# 160: 448x640 1 leaf_rust, 789.8ms
# 161: 448x640 1 leaf_rust, 789.8ms
# 162: 448x640 1 leaf_rust, 789.8ms
# 163: 448x640 4 leaf_healthys, 789.8ms
# 164: 448x640 1 leaf_scab, 789.8ms
# 165: 448x640 1 leaf_rust, 789.8ms
# 166: 448x640 2 leaf_healthys, 789.8ms
# 167: 448x640 1 leaf_rust, 789.8ms
# 168: 448x640 11 leaf_healthys, 789.8ms
# 169: 448x640 2 leaf_healthys, 789.8ms
# 170: 448x640 1 leaf_rust, 789.8ms
# 171: 448x640 1 leaf_rust, 789.8ms
# 172: 448x640 1 leaf_rust, 789.8ms
# Speed: 2.5ms preprocess, 789.8ms inference, 3.4ms postprocess per image at shape (1, 3, 448, 640)
# Memproses 173 gambar. Hasil akan disimpan di 'output_inference/'...
# Selesai!
