# %%
from ultralytics import YOLO

# %%
model = YOLO("predict/best.pt")
results = model.predict(source="predict/cropped_image.png", save=True)
# Out:
# image 1/1 c:\Users\abiyamf\Documents\Code Program\Thesis\random_experiment\predict\cropped_image.png: 416x640 1 frog-eye-leaf-spot, 5 frog-eye-leaf-spot_lessions, 34.9ms
# Speed: 7.7ms preprocess, 34.9ms inference, 39.5ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to C:\Users\abiyamf\Documents\Code Program\Thesis\random_experiment\runs\segment\predict

# %%
model = YOLO('yolo12m-seg.yaml') 

# Tampilkan informasi model
model.info()
# Out:
# YOLO12m-seg summary: 314 layers, 22,505,376 parameters, 22,505,360 gradients, 113.4 GFLOPs
# (314, 22505376, 22505360, 113.40436480000001)
